# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\volle\\OneDrive\\COLLEGE\\Senior\\Summer 23\\Mee 460\\Project 2'

# %%
os.chdir("C:\\users\\volle\\OneDrive\\COLLEGE\\Senior\\Summer 23\\Mee 460\\Rstudio AGAIN")
os.getcwd()
# Out:
# 'C:\\users\\volle\\OneDrive\\COLLEGE\\Senior\\Summer 23\\Mee 460\\Rstudio AGAIN'

# %%
from IPython import display
display.Image("error0.png")

# %%
from IPython import display
display.Image("error1.png")

# %%
from IPython import display
display.Image("error2.png")

# %%
from IPython import display
display.Image("error3.png")

# %%
from IPython import display
display.Image("error4.png")

# %%
from IPython import display
display.Image("error5.png")

# %%
from IPython import display
display.Image("error6.png")

# %%
from IPython import display
display.Image("error7.png")

# %%
from IPython import display
display.Image("error8.png")

# %%
from IPython import display
display.Image("error9.png")

# %%
from IPython import display
display.Image("error10.png")

# %%
from IPython import display
display.Image("error11.png")

# %%
from IPython import display
display.Image("error12.png")

# %%
from IPython import display
display.Image("error13.png")

# %%
from IPython import display
display.Image("error14.png")
