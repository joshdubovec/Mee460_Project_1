# %% [markdown]
# <b> MEE 460 Z1 Continuous Manufacturing Process </b>

# %% [markdown]
# <b> <h2> Continuous Manfacturing Process </b> </h2>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as snb

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\volle'

# %%
os.chdir("C:\\users\\volle\\Desktop\\MEE460 Project1")
os.getcwd()
# Out:
# 'C:\\users\\volle\\Desktop\\MEE460 Project1'

# %%
Data_df = pd.read_csv("Machine_Data_file_1.csv")

# %%
Data_df
# Out:
#            time_stamp  AmbientConditions_AmbientHumidity_U_Actual  \
# 0      3/6/2019 10:52                                       17.24
# 1      3/6/2019 10:52                                       17.24
# 2      3/6/2019 10:52                                       17.24
# 3      3/6/2019 10:52                                       17.24
# 4      3/6/2019 10:52                                       17.24
# ...               ...                                         ...
# 14083  3/6/2019 14:47                                       13.84
# 14084  3/6/2019 14:47                                       13.84
# 14085  3/6/2019 14:47                                       13.84
# 14086  3/6/2019 14:47                                       13.84
# 14087  3/6/2019 14:47                                       13.84
#
#        AmbientConditions_AmbientTemperature_U_Actual  \
# 0                                              23.53
# 1                                              23.53
# ...

# %%
Data_df.drop(Data_df.loc[:, 'Machine4_Temperature1_C_Actual':].columns, axis = 1, inplace = True)

# %%
Data_df["Error0"] = abs(Data_df["Stage1_Output_Measurement0_U_Actual"] - Data_df["Stage1_Output_Measurement0_U_Setpoint"])

# %%
Data_df
# Out:
#            time_stamp  AmbientConditions_AmbientHumidity_U_Actual  \
# 0      3/6/2019 10:52                                       17.24
# 1      3/6/2019 10:52                                       17.24
# 2      3/6/2019 10:52                                       17.24
# 3      3/6/2019 10:52                                       17.24
# 4      3/6/2019 10:52                                       17.24
# ...               ...                                         ...
# 14083  3/6/2019 14:47                                       13.84
# 14084  3/6/2019 14:47                                       13.84
# 14085  3/6/2019 14:47                                       13.84
# 14086  3/6/2019 14:47                                       13.84
# 14087  3/6/2019 14:47                                       13.84
#
#        AmbientConditions_AmbientTemperature_U_Actual  \
# 0                                              23.53
# 1                                              23.53
# ...

# %%
Data_df["Error1"] = abs(Data_df["Stage1_Output_Measurement1_U_Actual"] - Data_df["Stage1_Output_Measurement1_U_Setpoint"])

# %%
Data_df
# Out:
#            time_stamp  AmbientConditions_AmbientHumidity_U_Actual  \
# 0      3/6/2019 10:52                                       17.24
# 1      3/6/2019 10:52                                       17.24
# 2      3/6/2019 10:52                                       17.24
# 3      3/6/2019 10:52                                       17.24
# 4      3/6/2019 10:52                                       17.24
# ...               ...                                         ...
# 14083  3/6/2019 14:47                                       13.84
# 14084  3/6/2019 14:47                                       13.84
# 14085  3/6/2019 14:47                                       13.84
# 14086  3/6/2019 14:47                                       13.84
# 14087  3/6/2019 14:47                                       13.84
#
#        AmbientConditions_AmbientTemperature_U_Actual  \
# 0                                              23.53
# 1                                              23.53
# ...

# %%
Data_df["Error2"] = abs(Data_df["Stage1_Output_Measurement2_U_Actual"] - Data_df["Stage1_Output_Measurement2_U_Setpoint"])

# %%
Data_df["Error3"] = abs(Data_df["Stage1_Output_Measurement3_U_Actual"] - Data_df["Stage1_Output_Measurement3_U_Setpoint"])

# %%
Data_df["Error4"] = abs(Data_df["Stage1_Output_Measurement4_U_Actual"] - Data_df["Stage1_Output_Measurement4_U_Setpoint"])

# %%
Data_df
# Out:
#            time_stamp  AmbientConditions_AmbientHumidity_U_Actual  \
# 0      3/6/2019 10:52                                       17.24
# 1      3/6/2019 10:52                                       17.24
# 2      3/6/2019 10:52                                       17.24
# 3      3/6/2019 10:52                                       17.24
# 4      3/6/2019 10:52                                       17.24
# ...               ...                                         ...
# 14083  3/6/2019 14:47                                       13.84
# 14084  3/6/2019 14:47                                       13.84
# 14085  3/6/2019 14:47                                       13.84
# 14086  3/6/2019 14:47                                       13.84
# 14087  3/6/2019 14:47                                       13.84
#
#        AmbientConditions_AmbientTemperature_U_Actual  \
# 0                                              23.53
# 1                                              23.53
# ...

# %%
Data_df["Error5"] = abs(Data_df["Stage1_Output_Measurement5_U_Actual"] - Data_df["Stage1_Output_Measurement5_U_Setpoint"])
Data_df["Error6"] = abs(Data_df["Stage1_Output_Measurement6_U_Actual"] - Data_df["Stage1_Output_Measurement6_U_Setpoint"])
Data_df["Error7"] = abs(Data_df["Stage1_Output_Measurement7_U_Actual"] - Data_df["Stage1_Output_Measurement7_U_Setpoint"])
Data_df["Error8"] = abs(Data_df["Stage1_Output_Measurement8_U_Actual"] - Data_df["Stage1_Output_Measurement8_U_Setpoint"])
Data_df["Error9"] = abs(Data_df["Stage1_Output_Measurement9_U_Actual"] - Data_df["Stage1_Output_Measurement9_U_Setpoint"])

# %%
Data_df
# Out:
#            time_stamp  AmbientConditions_AmbientHumidity_U_Actual  \
# 0      3/6/2019 10:52                                       17.24
# 1      3/6/2019 10:52                                       17.24
# 2      3/6/2019 10:52                                       17.24
# 3      3/6/2019 10:52                                       17.24
# 4      3/6/2019 10:52                                       17.24
# ...               ...                                         ...
# 14083  3/6/2019 14:47                                       13.84
# 14084  3/6/2019 14:47                                       13.84
# 14085  3/6/2019 14:47                                       13.84
# 14086  3/6/2019 14:47                                       13.84
# 14087  3/6/2019 14:47                                       13.84
#
#        AmbientConditions_AmbientTemperature_U_Actual  \
# 0                                              23.53
# 1                                              23.53
# ...

# %%
Data_df["Error10"] = abs(Data_df["Stage1_Output_Measurement10_U_Actual"] - Data_df["Stage1_Output_Measurement10_U_Setpoint"])
Data_df["Error11"] = abs(Data_df["Stage1_Output_Measurement11_U_Actual"] - Data_df["Stage1_Output_Measurement11_U_Setpoint"])
Data_df["Error12"] = abs(Data_df["Stage1_Output_Measurement12_U_Actual"] - Data_df["Stage1_Output_Measurement12_U_Setpoint"])
Data_df["Error13"] = abs(Data_df["Stage1_Output_Measurement13_U_Actual"] - Data_df["Stage1_Output_Measurement13_U_Setpoint"])
Data_df["Error14"] = abs(Data_df["Stage1_Output_Measurement14_U_Actual"] - Data_df["Stage1_Output_Measurement14_U_Setpoint"])

# %%
Data_df
# Out:
#            time_stamp  AmbientConditions_AmbientHumidity_U_Actual  \
# 0      3/6/2019 10:52                                       17.24
# 1      3/6/2019 10:52                                       17.24
# 2      3/6/2019 10:52                                       17.24
# 3      3/6/2019 10:52                                       17.24
# 4      3/6/2019 10:52                                       17.24
# ...               ...                                         ...
# 14083  3/6/2019 14:47                                       13.84
# 14084  3/6/2019 14:47                                       13.84
# 14085  3/6/2019 14:47                                       13.84
# 14086  3/6/2019 14:47                                       13.84
# 14087  3/6/2019 14:47                                       13.84
#
#        AmbientConditions_AmbientTemperature_U_Actual  \
# 0                                              23.53
# 1                                              23.53
# ...

# %%
Data_df.to_excel("C:\\Users\\volle\\Desktop\\MEE460 Project1\\Project1 New Data Set.xlsx")

# %% [markdown]
# <img src="Josh orange workflow.PNG">
# <img src="Scatter plot of error2.png">
